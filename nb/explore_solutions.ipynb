# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from astropy.io import fits
import glob
# %matplotlib inline

# %%
rec_files = glob.glob("../data/reconstruction/test_*.txt")
rec_files.sort()
truth_data = {}
rec_data = {}
test_data = {}
for ii, rec_f in enumerate(rec_files[:40]):
    truth_f = rec_f.replace("data/reconstruction/test_idr", "data/truth_id")
    test_f = rec_f.replace("data/reconstruction/test_idr", "data/test_id")
    print(test_f, truth_f, rec_f)
    truth_data[ii] = np.loadtxt(truth_f)
    rec_data[ii] = np.loadtxt(rec_f)
    test_data[ii] = np.loadtxt(test_f)
# Out:
# ../data/test_id_1.txt ../data/truth_id_1.txt ../data/reconstruction/test_idr_1.txt
# ../data/test_id_101.txt ../data/truth_id_101.txt ../data/reconstruction/test_idr_101.txt
# ../data/test_id_105.txt ../data/truth_id_105.txt ../data/reconstruction/test_idr_105.txt
# ../data/test_id_107.txt ../data/truth_id_107.txt ../data/reconstruction/test_idr_107.txt
# ../data/test_id_109.txt ../data/truth_id_109.txt ../data/reconstruction/test_idr_109.txt
# ../data/test_id_11.txt ../data/truth_id_11.txt ../data/reconstruction/test_idr_11.txt
# ../data/test_id_111.txt ../data/truth_id_111.txt ../data/reconstruction/test_idr_111.txt
# ../data/test_id_113.txt ../data/truth_id_113.txt ../data/reconstruction/test_idr_113.txt
# ../data/test_id_115.txt ../data/truth_id_115.txt ../data/reconstruction/test_idr_115.txt
# ../data/test_id_117.txt ../data/truth_id_117.txt ../data/reconstruction/test_idr_117.txt
# ../data/test_id_119.txt ../data/truth_id_119.txt ../data/reconstruction/test_idr_119.txt
# ../data/test_id_121.txt ../data/truth_id_121.txt ../data/reconstruction/test_idr_121.txt
# ../data/test_id_123.txt ../data/truth_id_123.txt ../data/reconstruction/test_idr_123.txt
# ../data/test_id_125.txt ../data/truth_id_125.txt ../data/reconstruction/test_idr_125.txt
# ../data/test_id_127.txt ../data/truth_id_127.txt ../data/reconstruction/test_idr_127.txt
# ../data/test_id_129.txt ../data/truth_id_129.txt ../data/reconstruction/test_idr_129.txt
# ../data/test_id_13.txt ../data/truth_id_13.txt ../data/reconstruction/test_idr_13.txt
# ../data/test_id_131.txt ../data/truth_id_131.txt ../data/reconstruction/test_idr_131.txt
# ../data/test_id_133.txt ../data/truth_id_133.txt ../data/reconstruction/test_idr_133.txt
# ../data/test_id_135.txt ../data/truth_id_135.txt ../data/reconstruction/test_idr_135.txt
# ../data/test_id_139.txt ../data/truth_id_139.txt ../data/reconstruction/test_idr_139.txt
# ../data/test_id_141.txt ../data/truth_id_141.txt ../data/reconstruction/test_idr_141.txt
# ../data/test_id_143.txt ../data/truth_id_143.txt ../data/reconstruction/test_idr_143.txt
# ../data/test_id_145.txt ../data/truth_id_145.txt ../data/reconstruction/test_idr_145.txt
# ../data/test_id_147.txt ../data/truth_id_147.txt ../data/reconstruction/test_idr_147.txt
# ../data/test_id_149.txt ../data/truth_id_149.txt ../data/reconstruction/test_idr_149.txt
# ../data/test_id_15.txt ../data/truth_id_15.txt ../data/reconstruction/test_idr_15.txt
# ../data/test_id_151.txt ../data/truth_id_151.txt ../data/reconstruction/test_idr_151.txt
# ../data/test_id_153.txt ../data/truth_id_153.txt ../data/reconstruction/test_idr_153.txt
# ../data/test_id_155.txt ../data/truth_id_155.txt ../data/reconstruction/test_idr_155.txt
# ../data/test_id_157.txt ../data/truth_id_157.txt ../data/reconstruction/test_idr_157.txt
# ../data/test_id_159.txt ../data/truth_id_159.txt ../data/reconstruction/test_idr_159.txt
# ../data/test_id_161.txt ../data/truth_id_161.txt ../data/reconstruction/test_idr_161.txt
# ../data/test_id_163.txt ../data/truth_id_163.txt ../data/reconstruction/test_idr_163.txt
# ../data/test_id_165.txt ../data/truth_id_165.txt ../data/reconstruction/test_idr_165.txt
# ../data/test_id_167.txt ../data/truth_id_167.txt ../data/reconstruction/test_idr_167.txt
# ../data/test_id_169.txt ../data/truth_id_169.txt ../data/reconstruction/test_idr_169.txt
# ../data/test_id_17.txt ../data/truth_id_17.txt ../data/reconstruction/test_idr_17.txt
# ../data/test_id_171.txt ../data/truth_id_171.txt ../data/reconstruction/test_idr_171.txt
# ../data/test_id_173.txt ../data/truth_id_173.txt ../data/reconstruction/test_idr_173.txt

# %%
fileid=15

plt.figure(figsize=(20,4))

plt.plot(truth_data[fileid], label="Truth")
plt.plot(rec_data[fileid], label="Reconstruction")

x = np.arange(len(test_data[fileid]))
jj = test_data[fileid]>0

plt.scatter(x[jj], test_data[fileid][jj], s=30.0)
plt.xlim(0,800)
plt.legend()
